# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# read in all our data
data = pd.read_csv("google-play-store-apps/googleplaystore.csv")

# %%
data.sample(100)
# Out:
#                                                     App             Category  \
# 7070                                      bz Basel News   NEWS_AND_MAGAZINES
# 4235                                         Sonic Dash                 GAME
# 1466                                 Redfin Real Estate       HOUSE_AND_HOME
# 2406                                 PTA Content Master              MEDICAL
# 2909  Candy Camera - selfie, beauty camera, photo ed...          PHOTOGRAPHY
# 3175  Expedia Hotels, Flights & Car Rental Travel Deals     TRAVEL_AND_LOCAL
# 3013                                ESPN Fantasy Sports               SPORTS
# 5178                                            Replika               FAMILY
# 5264                         AJ Tracey Music and Lyrics               FAMILY
# 9674                      Masha and the Bear: Evolution               FAMILY
# 5146                                        Ah! Monster               FAMILY
# 3602                               White Noise for Baby            PARENTING
# 7755                          Next Island: Dino Village               FAMILY
# 745              NeuroNation - Focus and Brain Training            EDUCATION
# 3755                       Flipboard: News For Our Time   NEWS_AND_MAGAZINES
# 5037                                         AfterFocus          PHOTOGRAPHY
# 2919                              HD Camera for Android          PHOTOGRAPHY
# 888                                    IMDb Movies & TV        ENTERTAINMENT
# 8271                                           DC Rider  MAPS_AND_NAVIGATION
# 4033                          Discord - Chat for Gamers        COMMUNICATION
# 1436      Fabulous: Motivate Me! Meditate, Relax, Sleep   HEALTH_AND_FITNESS
# 6588                                           iFORA BP              MEDICAL
# 8498                               Discovery K!ds Play!               FAMILY
# 2762                     Tophatter - 90 Second Auctions             SHOPPING
# 5171                                           Cathy AH                TOOLS
# 9455                                       EJ messenger        COMMUNICATION
# 3529    Polaris Office - Word, Docs, Sheets, Slide, PDF         PRODUCTIVITY
# 1678                                        Word Search                 GAME
# 1319                                     Nike+ Run Club   HEALTH_AND_FITNESS
# 3491                                      Verizon Cloud         PRODUCTIVITY
# ...                                                 ...                  ...
# 5942     PROFESSOR SEE-BA LINGUAGENS E SUAS TECNOLOGIAS         PRODUCTIVITY
# 9576                                Narcos: Cartel Wars               FAMILY
# 1823                             Last Shelter: Survival                 GAME
# 5955                                      Hunt Buddy BC               SPORTS
# 6991  Adult Color By Number Book: Number Coloring Pages               FAMILY
# 2061                Kiddopia - Preschool Learning Games               FAMILY
# 5270                                      AJ Wallpapers      PERSONALIZATION
# 6961                          Benefit Extras Mobile App   HEALTH_AND_FITNESS
# 6638                                       BQ Llicència               SPORTS
# 7960                                        Resume Free         PRODUCTIVITY
# 9451                                         EJ Insight   NEWS_AND_MAGAZINES
# 1662                                                Pou                 GAME
# 1302  Home workouts - fat burning, abs, legs, arms,c...   HEALTH_AND_FITNESS
# 7935                     Planet of Cubes Survival Craft               FAMILY
# 517                       Christian Dating For Free App               DATING
# 7389                               Ci - Logistics Group             BUSINESS
# 3991                        Mobile C [ C/C++ Compiler ]               FAMILY
# 5830                                              Ay Up               FAMILY
# 5251                                  AJ Men's Grooming            LIFESTYLE
# 3632                         MyRadar NOAA Weather Radar              WEATHER
# 818                                 TeachersPayTeachers            EDUCATION
# 9608                                Yoong: Kick 'Em Up!               SPORTS
# 6980                              Mini Motor Racing WRT                 GAME
# 9608       Everyone                        Sports   December 16, 2015
# 6980       Everyone                        Racing    February 2, 2016
# 1338       Everyone              Health & Fitness      April 10, 2018
# 672      Mature 17+                        Dating       July 24, 2018
# 7629       Everyone  Books & Reference;Creativity      March 22, 2017
# 4620       Everyone                         Board   February 24, 2016
# 8703     Mature 17+                     Lifestyle   December 29, 2017
# 8618       Everyone               Personalization    January 31, 2018
# 5802           Teen                        Arcade        June 6, 2018
#
#              Current Ver         Android Ver
# 7070               1.4.0          5.0 and up
# 4235            3.8.5.Go          4.1 and up
# 1466               220.0          5.0 and up
# 2406                 2.1          2.2 and up
# 2909                4.47        4.0.3 and up
# 3175             18.30.0          5.0 and up
# 3013               5.3.0          4.4 and up
# 5178              1.5.49          4.4 and up
# 5264                 1.0        4.0.3 and up
# 9674               1.0.9          4.0 and up
# 5146               4.0.0          4.0 and up
# 3602               1.6.0          4.1 and up
# 7755                 1.0          5.0 and up
# 745   Varies with device        4.0.3 and up
# 3755  Varies with device  Varies with device
# 5037               2.1.0        4.0.3 and up
# 2919             4.6.0.0          4.2 and up
# 888   Varies with device  Varies with device
# 8271                 2.1          4.0 and up
# 4033               7.1.8          4.1 and up
# 1436                3.48          4.1 and up
# 6588               1.2.4        2.3.3 and up
# 8498          2.1.0.2173        4.0.3 and up
# 2762  Varies with device          4.4 and up
# 5171               1.0.4          4.1 and up
# 9455                 1.0          4.0 and up
# 3529              7.3.30          4.1 and up
# 1678               1.1.3          3.0 and up
# 1319              2.17.0          4.4 and up
# 3491  Varies with device          4.4 and up
# ...                  ...                 ...
# 5942                 1.0          4.0 and up
# 9576             1.24.09        4.0.3 and up
# 1823           1.250.078        4.0.3 and up
# 5955                 1.5        4.0.3 and up
# 6991                 2.9          4.4 and up
# 2061               1.1.2          5.0 and up
# 5270                 2.0        4.0.3 and up
# 6961                 6.0          5.0 and up
# 6638  Varies with device          4.0 and up
# 7960                 2.1        2.3.3 and up
# 9451                 1.0          4.0 and up
# 1662              1.4.77          4.0 and up
# 1302                 2.6          4.1 and up
# 7935               4.5.4          4.1 and up
# 517                 15.8          4.1 and up
# 7389               1.0.0          4.0 and up
# 3991               2.5.1        4.0.3 and up
# 5830               3.0.0          2.1 and up
# 5251                   5          4.1 and up
# 3632  Varies with device  Varies with device
# 818   Varies with device  Varies with device
# 9608               1.1.1        4.0.3 and up
# 6980  Varies with device        2.3.3 and up
# 1338               2.0.4        2.3.3 and up
# 672                  1.0        4.0.3 and up
# 7629                2.49          4.1 and up
# 4620               1.6.3        2.3.3 and up
# 8703       DPSTATUS1.0.1        4.0.3 and up
# 8618               1.5.3          4.0 and up
# 5802               1.0.7          4.1 and up
#
# [100 rows x 13 columns]

# %%
missing_values_count1 = data['Android Ver'].isnull().sum()

print("Missing values in Android Ver: ",missing_values_count1)
# Out:
# Missing values in Android Ver:  3

# %%
unique_android_ver = data['Android Ver'].unique()

print("Unique values in Android Ver: \n",unique_android_ver)
# Out:
# Unique values in Android Ver:
#  ['4.0.3 and up' '4.2 and up' '4.4 and up' '2.3 and up' '3.0 and up'
#  '4.1 and up' '4.0 and up' '2.3.3 and up' 'Varies with device'
#  '2.2 and up' '5.0 and up' '6.0 and up' '1.6 and up' '1.5 and up'
#  '2.1 and up' '7.0 and up' '5.1 and up' '4.3 and up' '4.0.3 - 7.1.1'
#  '2.0 and up' '3.2 and up' '4.4W and up' '7.1 and up' '7.0 - 7.1.1'
#  '8.0 and up' '5.0 - 8.0' '3.1 and up' '2.0.1 and up' '4.1 - 7.1.1' nan
#  '5.0 - 6.0' '1.0 and up' '2.2 - 7.1.1' '5.0 - 7.1.1']

# %%
count_android_ver = data['Android Ver'].value_counts()

print("Count of values in Android Ver: \n",count_android_ver)
# Out:
# Count of values in Android Ver:
#  4.1 and up            2451
# 4.0.3 and up          1501
# 4.0 and up            1375
# Varies with device    1362
# 4.4 and up             980
# 2.3 and up             652
# 5.0 and up             601
# 4.2 and up             394
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             243
# 3.0 and up             241
# 2.1 and up             134
# 1.6 and up             116
# 6.0 and up              60
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              24
# 1.5 and up              20
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 5.0 - 8.0                2
# 4.0.3 - 7.1.1            2
# 1.0 and up               2
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# 5.0 - 6.0                1
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
data['Android Ver'] = data['Android Ver'].replace(np.nan, 'Varies with device')

data['Android Ver'] = data['Android Ver'].replace('4.4W and up', '4.4 and up')

data['Android Ver'] = data['Android Ver'].replace('5.0 - 8.0', '5.0 and up till 8.0')

data['Android Ver'] = data['Android Ver'].replace('5.0 - 6.0', '5.0 and up till 6.0')

data['Android Ver'] = data['Android Ver'].replace('7.0 - 7.1.1', '7.0 and up till 7.1.1')

data['Android Ver'] = data['Android Ver'].replace('5.0 - 7.1.1', '5.0 and up till 7.1.1')

data['Android Ver'] = data['Android Ver'].replace('4.1 - 7.1.1', '4.1 and up till 7.1.1')

data['Android Ver'] = data['Android Ver'].replace('2.2 - 7.1.1', '2.2 and up till 7.1.1')

data['Android Ver'] = data['Android Ver'].replace('4.0.3 - 7.1.1', '4.0.3 and up till 7.1.1')

# %%
count_android_ver = data['Android Ver'].value_counts()

print("Count of values in Android Ver: \n",count_android_ver)
# Out:
# Count of values in Android Ver:
#  4.1 and up                 2451
# 4.0.3 and up               1501
# 4.0 and up                 1375
# Varies with device         1365
# 4.4 and up                  992
# 2.3 and up                  652
# 5.0 and up                  601
# 4.2 and up                  394
# 2.3.3 and up                281
# 2.2 and up                  244
# 4.3 and up                  243
# 3.0 and up                  241
# 2.1 and up                  134
# 1.6 and up                  116
# 6.0 and up                   60
# 7.0 and up                   42
# 3.2 and up                   36
# 2.0 and up                   32
# 5.1 and up                   24
# 1.5 and up                   20
# 3.1 and up                   10
# 2.0.1 and up                  7
# 8.0 and up                    6
# 7.1 and up                    3
# 4.0.3 and up till 7.1.1       2
# 5.0 and up till 8.0           2
# 1.0 and up                    2
# 5.0 and up till 6.0           1
# 7.0 and up till 7.1.1         1
# 4.1 and up till 7.1.1         1
# 2.2 and up till 7.1.1         1
# 5.0 and up till 7.1.1         1
# Name: Android Ver, dtype: int64

# %%
data['Android Ver'].value_counts().plot(kind='barh')

# Most of the apps in the dataset require that mobile phones has an android version that's higher than 4.1

# %%
missing_values_count2 = data['Last Updated'].isnull().sum()

print("Missing values in Last Updated: ",missing_values_count2)
# Out:
# Missing values in Last Updated:  0

# %%
unique_last_updated = data['Last Updated'].unique()

print("Unique values in Last Updated: \n",unique_last_updated)
# Out:
# Unique values in Last Updated:
#  ['January 7, 2018' 'January 15, 2018' 'August 1, 2018' ...
#  'January 20, 2014' 'February 16, 2014' 'March 23, 2014']

# %%
count_last_updated = data['Last Updated'].value_counts()

print("Count of values in Last Updated: \n",count_last_updated)
# Out:
# Count of values in Last Updated:
#  August 3, 2018        326
# August 2, 2018        304
# July 31, 2018         294
# August 1, 2018        285
# July 30, 2018         211
# July 25, 2018         164
# July 26, 2018         161
# August 6, 2018        158
# July 27, 2018         151
# July 24, 2018         148
# July 23, 2018         127
# July 16, 2018         126
# July 19, 2018         126
# July 18, 2018         123
# July 11, 2018         106
# August 4, 2018        105
# July 12, 2018         103
# July 5, 2018           93
# July 17, 2018          92
# July 3, 2018           90
# July 9, 2018           89
# July 20, 2018          88
# July 13, 2018          81
# May 24, 2018           69
# July 6, 2018           63
# June 27, 2018          63
# June 26, 2018          60
# June 25, 2018          56
# May 25, 2018           56
# June 13, 2018          54
#                      ...
# September 11, 2016      1
# January 25, 2013        1
# November 10, 2014       1
# November 4, 2014        1
# March 13, 2015          1
# June 30, 2014           1
# March 19, 2016          1
# June 23, 2011           1
# August 26, 2013         1
# May 18, 2013            1
# July 8, 2017            1
# May 13, 2017            1
# March 12, 2017          1
# June 12, 2013           1
# September 25, 2013      1
# January 1, 2015         1
# December 13, 2014       1
# May 14, 2017            1
# March 13, 2017          1
# October 29, 2015        1
# October 28, 2014        1
# February 8, 2016        1
# October 1, 2015         1
# June 27, 2012           1
# April 11, 2011          1
# October 1, 2013         1
# June 24, 2017           1
# May 13, 2015            1
# August 2, 2014          1
# June 19, 2012           1
# Name: Last Updated, Length: 1378, dtype: int64

# %%
col = data.columns[10]

data = data[data['Last Updated'] !='1.0.19']

# %%
count_last_updated = data['Last Updated'].value_counts()

print("Count of values in Last Updated: \n",count_last_updated)
# Out:
# Count of values in Last Updated:
#  August 3, 2018        326
# August 2, 2018        304
# July 31, 2018         294
# August 1, 2018        285
# July 30, 2018         211
# July 25, 2018         164
# July 26, 2018         161
# August 6, 2018        158
# July 27, 2018         151
# July 24, 2018         148
# July 23, 2018         127
# July 16, 2018         126
# July 19, 2018         126
# July 18, 2018         123
# July 11, 2018         106
# August 4, 2018        105
# July 12, 2018         103
# July 5, 2018           93
# July 17, 2018          92
# July 3, 2018           90
# July 9, 2018           89
# July 20, 2018          88
# July 13, 2018          81
# May 24, 2018           69
# July 6, 2018           63
# June 27, 2018          63
# June 26, 2018          60
# June 25, 2018          56
# May 25, 2018           56
# June 13, 2018          54
#                      ...
# May 9, 2013             1
# November 4, 2014        1
# January 1, 2015         1
# March 13, 2015          1
# June 30, 2014           1
# March 19, 2016          1
# June 23, 2011           1
# August 26, 2013         1
# May 18, 2013            1
# July 8, 2017            1
# May 13, 2017            1
# March 12, 2017          1
# June 12, 2013           1
# September 25, 2013      1
# November 10, 2014       1
# May 14, 2017            1
# September 11, 2016      1
# March 13, 2017          1
# October 29, 2015        1
# October 28, 2014        1
# February 8, 2016        1
# October 1, 2015         1
# June 27, 2012           1
# April 11, 2011          1
# October 1, 2013         1
# June 24, 2017           1
# May 13, 2015            1
# August 2, 2014          1
# December 13, 2014       1
# June 19, 2012           1
# Name: Last Updated, Length: 1377, dtype: int64

# %%
missing_values_count1 = data['Android Ver'].isnull().sum()

# look at the # of missing points in the first ten columns
print("Missing values in Android Ver: ",missing_values_count1)
# Out:
# Missing values in Android Ver:  0

# %%
missing_values_count1 = data['Rating'].isnull().sum()

# %%
missing_values_count1
# Out:
# 1474

# %%
data.boxplot(column='Rating', by='Android Ver',rot=90, fontsize=12, figsize=(10,10), grid=True)

# %%
months = data['Last Updated'].str.split(' ').str[0]
months[months=='January'] ="1"
months[months=='August'] ="8"
months[months=='June'] ="16"
months[months=='March'] ="3"
months[months=='September'] ="9"
months[months=='July'] ="7"
months[months=='October'] ="10"
months[months=='November'] ="11"
months[months=='May'] ="5"
months[months=='December'] ="12"
months[months=='February'] ="2"
months[months=='April'] ="4"
years = data['Last Updated'].str.split(', ').str[1]

temp = data['Last Updated'].str.split(',').str[0]

date = months+'-'+years

date
# Out:
# 0         1-2018
# 1         1-2018
# 2         8-2018
# 3        16-2018
# 4        16-2018
# 5         3-2017
# 6         4-2018
# 7        16-2018
# 8         9-2017
# 9         7-2018
# 10       10-2017
# 11        7-2018
# 12        4-2018
# 13       16-2018
# 14        8-2018
# 15       16-2018
# 16        7-2018
# 17       11-2017
# 18        8-2018
# 19        7-2018
# 20        4-2018
# 21        3-2018
# 22        7-2018
# 23        3-2018
# 24        7-2018
# 25        4-2018
# 26       10-2017
# 27        3-2018
# 28        7-2018
# 29        8-2017
#           ...
# 10811     7-2018
# 10812    16-2018
# 10813     7-2018
# 10814    16-2015
# 10815     7-2018
# 10816     8-2018
# 10817    10-2015
# 10818     5-2016
# 10819     8-2017
# 10820    16-2018
# 10821     5-2018
# 10822    12-2017
# 10823     4-2018
# 10824     7-2018
# 10825     2-2018
# 10826     3-2018
# 10827    16-2018
# 10828     5-2017
# 10829    16-2016
# 10830     1-2014
# 10831    16-2018
# 10832     2-2014
# 10833     3-2014
# 10834    16-2017
# 10835     9-2016
# 10836     7-2017
# 10837     7-2018
# 10838     1-2017
# 10839     1-2015
# 10840     7-2018
# Name: Last Updated, Length: 10840, dtype: object

# %%
data['Last Updated'] = date

# %%
len(data['Last Updated'].unique())
# Out:
# 88

# %%
plt.scatter(data['Last Updated'], data['Rating'])

# %%
data.groupby(['Last Updated']).Rating.mean().plot(kind='bar',figsize=(20,5),fontsize=12,rot=90)
